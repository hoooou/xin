# %%
import backtrader as bt
import datetime as datetime

# %%
    # 创建交易数据集
data = bt.feeds.YahooFinanceCSVData(
    dataname="orcl-1995-2014-1.csv",
    # 数据必须大于fromdate
    fromdate=datetime.datetime(2000, 1, 1),
    # 数据必须小于todate
    todate=datetime.datetime(2000, 12, 31),
    reverse=False)

# %%
# 创建策略继承bt.Strategy
class TestStrategy(bt.Strategy):
    params = (
        # 持仓够5个单位就卖出
        ('exitbars', 5),
        ('maperiod', 5),
    )

    def log(self, txt, dt=None):
        # 记录策略的执行日志
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        # 保存收盘价的引用
        self.dataclose = self.datas[0].close
        self.sma=bt.indicators.MovingAverageSimple(self.datas[0],period=self.params.maperiod)
        # 跟踪挂单
        self.order = None
        # 买入价格和手续费
        self.buyprice = None
        self.buycomm = None

    # 交易状态通知，一买一卖算交易

    def notify_trade(self, trade):
        if not trade.isclosed:
            return
        self.log('交易利润, 毛利润 %.2f, 净利润 %.2f' %
                 (trade.pnl, trade.pnlcomm))

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # broker 提交/接受了，买/卖订单则什么都不做
            return

        # 检查一个订单是否完成
        # 注意: 当资金不足时，broker会拒绝订单
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(
                    '已买入, 价格: %.2f, 费用: %.2f, 佣金 %.2f' %
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm))
                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm

            elif order.issell():
                self.log('已卖出, 价格: %.2f, 费用: %.2f, 佣金 %.2f' %
                         (order.executed.price,
                          order.executed.value,
                          order.executed.comm))
                self.log('已卖出, 数量: %s' %
                         (order.executed.size))

            # 记录当前交易数量
            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('订单取消/保证金不足/拒绝')

        # 其他状态记录为：无挂起订单
        self.order = None

    def next(self):
        # 记录收盘价
        self.log('Close, %.2f' % self.dataclose[0])

        # 如果有订单正在挂起，不操作
        if self.order:
            return

        # 如果没有持仓则买入
        if not self.position:
            # 今天的收盘价 < 昨天收盘价
            if self.dataclose[0] < self.dataclose[-1]:
                # 昨天收盘价 < 前天的收盘价
                if self.dataclose[-1] < self.dataclose[-2]:
                    # 买入
                    self.log('买入, %.2f' % self.dataclose[0])
                    # 跟踪订单避免重复
                    self.order = self.buy()
        else:
            # 如果已经持仓，且当前交易数据量在买入后5个单位后
            if len(self) >= (self.bar_executed + self.params.exitbars):
                # 全部卖出
                self.log('卖出, %.2f' % self.dataclose[0])
                # 跟踪订单避免重复
                self.order = self.sell()

# %%
cerebro=bt.Cerebro();
cerebro.broker.setcash(100000.0)
    # 设置佣金为0.001,除以100去掉%号
cerebro.broker.setcommission(commission=0.001)
cerebro.addsizer(bt.sizers.FixedSize,stake=10)
cerebro.adddata(data)
print("资金:%.2f" % cerebro.broker.getvalue())
# Out:
# 资金:100000.00

# %%
cerebro.strats.clear()
cerebro.addstrategy(TestStrategy)
print("之前资金:%.2f" % cerebro.broker.getvalue())
cerebro.run()
print("最后资金:%.2f" % cerebro.broker.getvalue())
# Out:
# 之前资金:100000.00
# 2000-01-03, Close, 27.85
# 2000-01-04, Close, 25.39
# 2000-01-05, Close, 24.05
# 2000-01-05, 买入, 24.05
# 2000-01-06, 已买入, 价格: 23.61, 费用: 236.10, 佣金 0.24
# 2000-01-06, Close, 22.63
# 2000-01-07, Close, 24.37
# 2000-01-10, Close, 27.29
# 2000-01-11, Close, 26.49
# 2000-01-12, Close, 24.90
# 2000-01-13, Close, 24.77
# 2000-01-13, 卖出, 24.77
# 2000-01-14, 已卖出, 价格: 25.70, 费用: 236.10, 佣金 0.26
# 2000-01-14, 已卖出, 数量: -10
# 2000-01-14, 交易利润, 毛利润 20.90, 净利润 20.41
# 2000-01-14, Close, 25.18
# 2000-01-18, Close, 26.23
# 2000-01-19, Close, 26.93
# 2000-01-20, Close, 27.94
# 2000-01-21, Close, 28.14
# 2000-01-24, Close, 25.55
# 2000-01-25, Close, 26.61
# 2000-01-26, Close, 25.96
# 2000-01-27, Close, 24.43
# 2000-01-27, 买入, 24.43
# 2000-01-28, 已买入, 价格: 24.28, 费用: 242.80, 佣金 0.24
# 2000-01-28, Close, 22.34
# 2000-01-31, Close, 23.55
# 2000-02-01, Close, 25.46
# 2000-02-02, Close, 25.61
# 2000-02-03, Close, 26.73
# 2000-02-04, Close, 27.26
# 2000-02-04, 卖出, 27.26
# 2000-02-07, 已卖出, 价格: 27.96, 费用: 242.80, 佣金 0.28
# 2000-02-07, 已卖出, 数量: -10
# 2000-02-07, 交易利润, 毛利润 36.80, 净利润 36.28
# 2000-02-07, Close, 28.26
# 2000-02-08, Close, 28.08
# 2000-02-09, Close, 28.26
# 2000-02-10, Close, 29.38
# 2000-02-11, Close, 28.14
# 2000-02-14, Close, 29.32
# 2000-02-15, Close, 28.94
# 2000-02-16, Close, 28.88
# 2000-02-16, 买入, 28.88
# 2000-02-17, 已买入, 价格: 29.12, 费用: 291.20, 佣金 0.29
# 2000-02-17, Close, 29.06
# 2000-02-18, Close, 27.61
# 2000-02-22, Close, 27.97
# 2000-02-23, Close, 29.73
# 2000-02-24, Close, 29.20
# 2000-02-25, Close, 33.30
# 2000-02-25, 卖出, 33.30
# 2000-02-28, 已卖出, 价格: 33.60, 费用: 291.20, 佣金 0.34
# 2000-02-28, 已卖出, 数量: -10
# 2000-02-28, 交易利润, 毛利润 44.80, 净利润 44.17
# 2000-02-28, Close, 32.36
# 2000-02-29, Close, 35.01
# 2000-03-01, Close, 33.71
# 2000-03-02, Close, 32.30
# 2000-03-02, 买入, 32.30
# 2000-03-03, 已买入, 价格: 33.53, 费用: 335.30, 佣金 0.34
# 2000-03-03, Close, 35.36
# 2000-03-06, Close, 35.72
# 2000-03-07, Close, 35.33
# 2000-03-08, Close, 39.19
# 2000-03-09, Close, 39.61
# 2000-03-10, Close, 38.49
# 2000-03-10, 卖出, 38.49
# 2000-03-13, 已卖出, 价格: 37.01, 费用: 335.30, 佣金 0.37
# 2000-03-13, 已卖出, 数量: -10
# 2000-03-13, 交易利润, 毛利润 34.80, 净利润 34.09
# 2000-03-13, Close, 37.13
# 2000-03-13, 买入, 37.13
# 2000-03-14, 已买入, 价格: 38.61, 费用: 386.10, 佣金 0.39
# 2000-03-14, Close, 36.31
# 2000-03-15, Close, 37.07
# 2000-03-16, Close, 38.63
# 2000-03-17, Close, 37.63
# 2000-03-20, Close, 36.84
# 2000-03-21, Close, 38.04
# 2000-03-21, 卖出, 38.04
# 2000-03-22, 已卖出, 价格: 38.20, 费用: 386.10, 佣金 0.38
# 2000-03-22, 已卖出, 数量: -10
# 2000-03-22, 交易利润, 毛利润 -4.10, 净利润 -4.87
# 2000-03-22, Close, 39.64
# 2000-03-23, Close, 40.96
# 2000-03-24, Close, 41.02
# 2000-03-27, Close, 41.70
# 2000-03-28, Close, 40.81
# 2000-03-29, Close, 38.90
# 2000-03-29, 买入, 38.90
# 2000-03-30, 已买入, 价格: 37.01, 费用: 370.10, 佣金 0.37
# 2000-03-30, Close, 36.98
# 2000-03-31, Close, 36.81
# 2000-04-03, Close, 36.25
# 2000-04-04, Close, 35.80
# 2000-04-05, Close, 36.90
# 2000-04-06, Close, 38.75
# 2000-04-06, 卖出, 38.75
# 2000-04-07, 已卖出, 价格: 39.46, 费用: 370.10, 佣金 0.39
# 2000-04-07, 已卖出, 数量: -10
# 2000-04-07, 交易利润, 毛利润 24.50, 净利润 23.74
# 2000-04-07, Close, 41.08
# 2000-04-10, Close, 38.90
# 2000-04-11, Close, 36.48
# 2000-04-11, 买入, 36.48
# 2000-04-12, 已买入, 价格: 36.75, 费用: 367.50, 佣金 0.37
# 2000-04-12, Close, 34.48
# 2000-04-13, Close, 33.92
# 2000-04-14, Close, 29.47
# 2000-04-17, Close, 35.27
# 2000-04-18, Close, 37.22
# 2000-04-19, Close, 35.16
# 2000-04-19, 卖出, 35.16
# 2000-04-20, 已卖出, 价格: 34.80, 费用: 367.50, 佣金 0.35
# 2000-04-20, 已卖出, 数量: -10
# 2000-04-20, 交易利润, 毛利润 -19.50, 净利润 -20.22
# 2000-04-20, Close, 33.39
# 2000-04-20, 买入, 33.39
# 2000-04-24, 已买入, 价格: 31.76, 费用: 317.60, 佣金 0.32
# 2000-04-24, Close, 34.15
# 2000-04-25, Close, 35.63
# 2000-04-26, Close, 34.04
# 2000-04-27, Close, 36.45
# 2000-04-28, Close, 37.69
# 2000-05-01, Close, 37.57
# 2000-05-01, 卖出, 37.57
# 2000-05-02, 已卖出, 价格: 37.22, 费用: 317.60, 佣金 0.37
# 2000-05-02, 已卖出, 数量: -10
# 2000-05-02, 交易利润, 毛利润 54.60, 净利润 53.91
# 2000-05-02, Close, 36.69
# 2000-05-02, 买入, 36.69
# 2000-05-03, 已买入, 价格: 36.25, 费用: 362.50, 佣金 0.36
# 2000-05-03, Close, 35.75
# 2000-05-04, Close, 35.01
# 2000-05-05, Close, 36.22
# 2000-05-08, Close, 34.10
# 2000-05-09, Close, 33.95
# 2000-05-10, Close, 31.89
# 2000-05-10, 卖出, 31.89
# 2000-05-11, 已卖出, 价格: 32.51, 费用: 362.50, 佣金 0.33
# 2000-05-11, 已卖出, 数量: -10
# 2000-05-11, 交易利润, 毛利润 -37.40, 净利润 -38.09
# 2000-05-11, Close, 34.13
# 2000-05-12, Close, 34.98
# 2000-05-15, Close, 36.31
# 2000-05-16, Close, 37.34
# 2000-05-17, Close, 36.87
# 2000-05-18, Close, 34.45
# 2000-05-18, 买入, 34.45
# 2000-05-19, 已买入, 价格: 33.94, 费用: 339.40, 佣金 0.34
# 2000-05-19, Close, 33.03
# 2000-05-22, Close, 31.97
# 2000-05-23, Close, 29.53
# 2000-05-24, Close, 30.29
# 2000-05-25, Close, 31.33
# 2000-05-26, Close, 31.59
# 2000-05-26, 卖出, 31.59
# 2000-05-30, 已卖出, 价格: 32.48, 费用: 339.40, 佣金 0.32
# 2000-05-30, 已卖出, 数量: -10
# 2000-05-30, 交易利润, 毛利润 -14.60, 净利润 -15.26
# 2000-05-30, Close, 34.98
# 2000-05-31, Close, 33.89
# 2000-06-01, Close, 36.72
# 2000-06-02, Close, 37.81
# 2000-06-05, Close, 38.16
# 2000-06-06, Close, 36.34
# 2000-06-07, Close, 37.72
# 2000-06-08, Close, 38.84
# 2000-06-09, Close, 38.99
# 2000-06-12, Close, 37.99
# 2000-06-13, Close, 38.52
# 2000-06-14, Close, 37.25
# 2000-06-15, Close, 38.90
# 2000-06-16, Close, 38.60
# 2000-06-19, Close, 40.55
# 2000-06-20, Close, 40.57
# 2000-06-21, Close, 40.64
# 2000-06-22, Close, 38.43
# 2000-06-23, Close, 37.48
# 2000-06-23, 买入, 37.48
# 2000-06-26, 已买入, 价格: 37.84, 费用: 378.40, 佣金 0.38
# 2000-06-26, Close, 38.99
# 2000-06-27, Close, 38.78
# 2000-06-28, Close, 39.11
# 2000-06-29, Close, 38.13
# 2000-06-30, Close, 39.64
# 2000-07-03, Close, 37.81
# 2000-07-03, 卖出, 37.81
# 2000-07-05, 已卖出, 价格: 36.22, 费用: 378.40, 佣金 0.36
# 2000-07-05, 已卖出, 数量: -10
# 2000-07-05, 交易利润, 毛利润 -16.20, 净利润 -16.94
# 2000-07-05, Close, 34.10
# 2000-07-05, 买入, 34.10
# 2000-07-06, 已买入, 价格: 33.84, 费用: 338.40, 佣金 0.34
# 2000-07-06, Close, 35.66
# 2000-07-07, Close, 35.78
# 2000-07-10, Close, 34.95
# 2000-07-11, Close, 34.10
# 2000-07-12, Close, 35.22
# 2000-07-13, Close, 35.72
# 2000-07-13, 卖出, 35.72
# 2000-07-14, 已卖出, 价格: 35.92, 费用: 338.40, 佣金 0.36
# 2000-07-14, 已卖出, 数量: -10
# 2000-07-14, 交易利润, 毛利润 20.80, 净利润 20.10
# 2000-07-14, Close, 35.89
# 2000-07-17, Close, 35.89
# 2000-07-18, Close, 34.98
# 2000-07-19, Close, 34.77
# 2000-07-19, 买入, 34.77
# 2000-07-20, 已买入, 价格: 35.28, 费用: 352.80, 佣金 0.35
# 2000-07-20, Close, 36.84
# 2000-07-21, Close, 35.57
# 2000-07-24, Close, 35.36
# 2000-07-25, Close, 35.83
# 2000-07-26, Close, 36.19
# 2000-07-27, Close, 35.39
# 2000-07-27, 卖出, 35.39
# 2000-07-28, 已卖出, 价格: 35.42, 费用: 352.80, 佣金 0.35
# 2000-07-28, 已卖出, 数量: -10
# 2000-07-28, 交易利润, 毛利润 1.40, 净利润 0.69
# 2000-07-28, Close, 34.13
# 2000-07-28, 买入, 34.13
# 2000-07-31, 已买入, 价格: 33.83, 费用: 338.30, 佣金 0.34
# 2000-07-31, Close, 35.45
# 2000-08-01, Close, 34.48
# 2000-08-02, Close, 34.48
# 2000-08-03, Close, 36.51
# 2000-08-04, Close, 38.46
# 2000-08-07, Close, 38.60
# 2000-08-07, 卖出, 38.60
# 2000-08-08, 已卖出, 价格: 38.19, 费用: 338.30, 佣金 0.38
# 2000-08-08, 已卖出, 数量: -10
# 2000-08-08, 交易利润, 毛利润 43.60, 净利润 42.88
# 2000-08-08, Close, 39.13
# 2000-08-09, Close, 38.37
# 2000-08-10, Close, 37.75
# 2000-08-10, 买入, 37.75
# 2000-08-11, 已买入, 价格: 37.69, 费用: 376.90, 佣金 0.38
# 2000-08-11, Close, 38.25
# 2000-08-14, Close, 38.84
# 2000-08-15, Close, 38.31
# 2000-08-16, Close, 38.28
# 2000-08-17, Close, 39.58
# 2000-08-18, Close, 38.34
# 2000-08-18, 卖出, 38.34
# 2000-08-21, 已卖出, 价格: 38.72, 费用: 376.90, 佣金 0.39
# 2000-08-21, 已卖出, 数量: -10
# 2000-08-21, 交易利润, 毛利润 10.30, 净利润 9.54
# 2000-08-21, Close, 39.22
# 2000-08-22, Close, 39.40
# 2000-08-23, Close, 39.08
# 2000-08-24, Close, 39.93
# 2000-08-25, Close, 39.90
# 2000-08-28, Close, 40.90
# 2000-08-29, Close, 41.37
# 2000-08-30, Close, 41.61
# 2000-08-31, Close, 42.88
# 2000-09-01, Close, 43.67
# 2000-09-05, Close, 42.94
# 2000-09-06, Close, 42.08
# 2000-09-06, 买入, 42.08
# 2000-09-07, 已买入, 价格: 42.50, 费用: 425.00, 佣金 0.42
# 2000-09-07, Close, 43.00
# 2000-09-08, Close, 40.81
# 2000-09-11, Close, 39.34
# 2000-09-12, Close, 37.43
# 2000-09-13, Close, 38.57
# 2000-09-14, Close, 40.05
# 2000-09-14, 卖出, 40.05
# 2000-09-15, 已卖出, 价格: 38.24, 费用: 425.00, 佣金 0.38
# 2000-09-15, 已卖出, 数量: -10
# 2000-09-15, 交易利润, 毛利润 -42.60, 净利润 -43.41
# 2000-09-15, Close, 36.92
# 2000-09-18, Close, 36.06
# 2000-09-18, 买入, 36.06
# 2000-09-19, 已买入, 价格: 36.52, 费用: 365.20, 佣金 0.37
# 2000-09-19, Close, 37.40
# 2000-09-20, Close, 37.69
# 2000-09-21, Close, 37.22
# 2000-09-22, Close, 38.07
# 2000-09-25, Close, 37.13
# 2000-09-26, Close, 37.46
# 2000-09-26, 卖出, 37.46
# 2000-09-27, 已卖出, 价格: 37.81, 费用: 365.20, 佣金 0.38
# 2000-09-27, 已卖出, 数量: -10
# 2000-09-27, 交易利润, 毛利润 12.90, 净利润 12.16
# 2000-09-27, Close, 37.66
# 2000-09-28, Close, 38.42
# 2000-09-29, Close, 37.13
# 2000-10-02, Close, 37.13
# 2000-10-03, Close, 32.77
# 2000-10-04, Close, 32.12
# 2000-10-04, 买入, 32.12
# 2000-10-05, 已买入, 价格: 32.21, 费用: 322.10, 佣金 0.32
# 2000-10-05, Close, 32.21
# 2000-10-06, Close, 31.89
# 2000-10-09, Close, 31.47
# 2000-10-10, Close, 30.47
# 2000-10-11, Close, 29.35
# 2000-10-12, Close, 29.70
# 2000-10-12, 卖出, 29.70
# 2000-10-13, 已卖出, 价格: 29.23, 费用: 322.10, 佣金 0.29
# 2000-10-13, 已卖出, 数量: -10
# 2000-10-13, 交易利润, 毛利润 -29.80, 净利润 -30.41
# 2000-10-13, Close, 33.59
# 2000-10-16, Close, 32.59
# 2000-10-17, Close, 31.77
# 2000-10-17, 买入, 31.77
# 2000-10-18, 已买入, 价格: 29.76, 费用: 297.60, 佣金 0.30
# 2000-10-18, Close, 31.65
# 2000-10-19, Close, 34.30
# 2000-10-20, Close, 33.24
# 2000-10-23, Close, 32.12
# 2000-10-24, Close, 33.77
# 2000-10-25, Close, 32.42
# 2000-10-25, 卖出, 32.42
# 2000-10-26, 已卖出, 价格: 32.77, 费用: 297.60, 佣金 0.33
# 2000-10-26, 已卖出, 数量: -10
# 2000-10-26, 交易利润, 毛利润 30.10, 净利润 29.47
# 2000-10-26, Close, 32.12
# 2000-10-26, 买入, 32.12
# 2000-10-27, 已买入, 价格: 32.53, 费用: 325.30, 佣金 0.33
# 2000-10-27, Close, 32.24
# 2000-10-30, Close, 29.82
# 2000-10-31, Close, 31.12
# 2000-11-01, Close, 29.59
# 2000-11-02, Close, 27.88
# 2000-11-03, Close, 28.58
# 2000-11-03, 卖出, 28.58
# 2000-11-06, 已卖出, 价格: 28.94, 费用: 325.30, 佣金 0.29
# 2000-11-06, 已卖出, 数量: -10
# 2000-11-06, 交易利润, 毛利润 -35.90, 净利润 -36.51
# 2000-11-06, Close, 26.35
# 2000-11-07, Close, 25.05
# 2000-11-07, 买入, 25.05
# 2000-11-08, 已买入, 价格: 25.82, 费用: 258.20, 佣金 0.26
# 2000-11-08, Close, 23.40
# 2000-11-09, Close, 25.64
# 2000-11-10, Close, 23.99
# 2000-11-13, Close, 23.34
# 2000-11-14, Close, 26.76
# 2000-11-15, Close, 27.23
# 2000-11-15, 卖出, 27.23
# 2000-11-16, 已卖出, 价格: 27.10, 费用: 258.20, 佣金 0.27
# 2000-11-16, 已卖出, 数量: -10
# 2000-11-16, 交易利润, 毛利润 12.80, 净利润 12.27
# 2000-11-16, Close, 25.81
# 2000-11-17, Close, 27.17
# 2000-11-20, Close, 23.34
# 2000-11-21, Close, 22.51
# 2000-11-21, 买入, 22.51
# 2000-11-22, 已买入, 价格: 22.28, 费用: 222.80, 佣金 0.22
# 2000-11-22, Close, 21.04
# 2000-11-24, Close, 22.75
# 2000-11-27, Close, 21.81
# 2000-11-28, Close, 21.36
# 2000-11-29, Close, 21.57
# 2000-11-30, Close, 24.99
# 2000-11-30, 卖出, 24.99
# 2000-12-01, 已卖出, 价格: 24.87, 费用: 222.80, 佣金 0.25
# 2000-12-01, 已卖出, 数量: -10
# 2000-12-01, 交易利润, 毛利润 25.90, 净利润 25.43
# 2000-12-01, Close, 24.93
# 2000-12-04, Close, 26.58
# 2000-12-05, Close, 29.70
# 2000-12-06, Close, 28.47
# 2000-12-07, Close, 26.70
# 2000-12-07, 买入, 26.70
# 2000-12-08, 已买入, 价格: 28.35, 费用: 283.50, 佣金 0.28
# 2000-12-08, Close, 28.35
# 2000-12-11, Close, 30.12
# 2000-12-12, Close, 29.00
# 2000-12-13, Close, 26.76
# 2000-12-14, Close, 25.93
# 2000-12-15, Close, 26.93
# 2000-12-15, 卖出, 26.93
# 2000-12-18, 已卖出, 价格: 28.29, 费用: 283.50, 佣金 0.28
# 2000-12-18, 已卖出, 数量: -10
# 2000-12-18, 交易利润, 毛利润 -0.60, 净利润 -1.17
# 2000-12-18, Close, 30.18
# 2000-12-19, Close, 28.88
# 2000-12-20, Close, 26.88
# 2000-12-20, 买入, 26.88
# 2000-12-21, 已买入, 价格: 26.23, 费用: 262.30, 佣金 0.26
# 2000-12-21, Close, 27.82
# 2000-12-22, Close, 30.06
# 2000-12-26, Close, 29.17
# 2000-12-27, Close, 28.94
# 2000-12-28, Close, 29.29
# 2000-12-29, Close, 27.41
# 2000-12-29, 卖出, 27.41
# 最后资金:100169.80
